# %%
from ultralytics import YOLO
model = YOLO("yolov10n.pt")
image_path = "/Users/anastasia/Desktop/YOLOv10_2/data/images/Cat and dog image.jpeg"
results = model.predict(image_path)

results[0].show()

for box in results[0].boxes:
    print(f"Coordinates: {box.xyxy}, Class: {box.cls}, Confidence: {box.conf}")
# Out:
# image 1/1 /Users/anastasia/Desktop/YOLOv10_2/data/images/Cat and dog image.jpeg: 416x640 2 cats, 1 dog, 104.8ms
# Speed: 8.6ms preprocess, 104.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# Coordinates: tensor([[  1.3153, 185.0506, 501.3058, 480.8881]]), Class: tensor([15.]), Confidence: tensor([0.7220])
# Coordinates: tensor([[416.8925,  61.3441, 800.0000, 484.7032]]), Class: tensor([16.]), Confidence: tensor([0.3132])
# Coordinates: tensor([[213.4616, 184.0531, 499.7064, 482.7872]]), Class: tensor([15.]), Confidence: tensor([0.3034])

# %% [markdown]
# ![image.png](attachment:b955e17c-c26f-4868-9b96-3419afc88228.png)

# %% [markdown]
# ![image.png](attachment:375db86b-82a6-476c-8deb-9aa6d0648883.png)
